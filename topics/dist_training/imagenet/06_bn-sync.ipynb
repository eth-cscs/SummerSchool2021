# %%
import os
import ipcmagic
from ipcmagic import utilities
# %ipcluster start -n {int(os.environ['SLURM_NNODES'])} --mpi
# Out:
# IPCluster is ready! (6 seconds)

# %%
# %%px
# import os
# import math
# import glob
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# import tensorflow as tf
# import albumentations as alb
# import horovod.tensorflow.keras as hvd
#
# AUTO = tf.data.experimental.AUTOTUNE
#
# epochs = 50
# batch_size = 128
# valid_samples, train_samples = 50000, 1281167
#
# hvd.init()
#
# num_nodes, node_id = hvd.size(), hvd.rank()
# cache_train = (num_nodes >= 4)
# lr = 0.1 * num_nodes
#
# global_batch_size = (batch_size * num_nodes)
# validation_steps = math.ceil(valid_samples / global_batch_size)
# steps_per_epoch = round(train_samples / global_batch_size)
#
# print(num_nodes, node_id, cache_train, lr, validation_steps, steps_per_epoch)
# Out:
# [stdout:0] 2 0 False 0.2 196 5005
# [stdout:1] 2 1 False 0.2 196 5005

# %%
# %%px
# train_files = sorted(glob.glob('/scratch/snx3000/datasets/imagenet/ILSVRC2012_1k/train/*'))
# valid_files = sorted(glob.glob('/scratch/snx3000/datasets/imagenet/ILSVRC2012_1k/validation/*'))
# print(len(train_files), len(valid_files))
# Out:
# [stdout:0] 1024 128
# [stdout:1] 1024 128

# %%
# %%px
# image_shape = (224, 224)
#
# def process_image(serialized_example, transforms):
#     ''' decode and augment images '''
#     features = tf.io.parse_single_example(
#         serialized_example,
#         features={
#             'image/encoded': tf.io.FixedLenFeature([], tf.string),
#             'image/class/label': tf.io.FixedLenFeature([], tf.int64),
#         })
#     image = tf.image.decode_jpeg(features['image/encoded'], channels=3)
#     label = tf.cast(features['image/class/label'], tf.int64) - 1  # [0-999]
#
#     image_aug = lambda img: transforms(image=img)["image"]
#     aug_img = tf.numpy_function(func=image_aug, inp=[image], Tout=tf.float32)
#     return aug_img, label
#
#
# train_transforms = alb.Compose([
#             alb.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=30),
#             alb.HorizontalFlip(p=0.5),
#             alb.OneOf([ # Add or remove noise
#                 alb.GaussNoise(var_limit=(50, 200)),
#                 alb.ImageCompression(quality_lower=80, quality_upper=95),
#                 alb.GaussianBlur(sigma_limit=(2, 10)),
#             ], p=1),
#             alb.SomeOf([ # Color ops
#                 alb.ToGray(p=0.1),
#                 alb.Equalize(by_channels=False),
#                 alb.RGBShift(r_shift_limit=10, g_shift_limit=10, b_shift_limit=10),
#                 alb.RandomGamma(gamma_limit=(90, 110)),
#                 alb.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=10, val_shift_limit=10),
#                 alb.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.2, 0.2)),
#             ], n=2),
#             alb.RandomResizedCrop(*image_shape, scale=(0.9, 1.1), ratio=(0.9, 1.1)),
#             alb.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#         ])
#
# valid_transforms = alb.Compose([
#             alb.SmallestMaxSize(max_size=image_shape[0]),
#             alb.CenterCrop(*image_shape),
#             alb.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#         ])

# %%
# %%px
# def get_ds(tfrecords,
#            transforms,
#            batch_size,
#            num_nodes,
#            node_id,
#            seed=42,
#            cache=False,
#            repeat=False,
#            shuffle_buffer=None,
#           ):
#     dataset = tf.data.Dataset.list_files(tfrecords,
#                                          shuffle=(not cache), # no point shuffling if we cache it later
#                                          seed=seed)
#     dataset = dataset.shard(num_shards=num_nodes,
#                             index=node_id)
#     dataset = dataset.interleave(tf.data.TFRecordDataset,
#                                  cycle_length=4,
#                                  block_length=1,
#                                  num_parallel_calls=AUTO)
#
#     if cache:
#         # caching has to be done before repeat/shuffle
#         dataset = dataset.cache()
#     if repeat:
#         dataset = dataset.repeat()
#     if shuffle_buffer:
#         dataset = dataset.shuffle(buffer_size=shuffle_buffer,
#                                   reshuffle_each_iteration=True,
#                                   seed=seed)
#
#     # decode and augment images
#     decode_aug = lambda img: process_image(img, transforms)
#     dataset = dataset.map(decode_aug, num_parallel_calls=AUTO)
#
#     dataset = dataset.batch(batch_size)
#     dataset = dataset.prefetch(buffer_size=AUTO)
#     return dataset
#
# valid_ds = get_ds(valid_files, valid_transforms, batch_size, num_nodes, node_id, cache=True)
# train_ds = get_ds(train_files, train_transforms, batch_size, num_nodes, node_id,
#                   shuffle_buffer=1024, repeat=True, cache=cache_train)

# %%
# %%px
# %load_ext autoreload
# %autoreload 2
#
# from tensorflow.python.keras.layers import VersionAwareLayers
# from horovod.tensorflow.sync_batch_norm import SyncBatchNormalization
#
# class SyncedLayers(VersionAwareLayers):
#   """Overload internal utility to access layers in a V1/V2-aware fashion to
#      use synchronized layers, i.e.: SyncedLayers().BatchNormalization == SyncBatchNormalization
#   """
#   def __getattr__(self, name):
#     if name is 'BatchNormalization':
#         return SyncBatchNormalization
#     return super().__getattr__(name)
#
# ## Let's test it
# print(SyncedLayers().Dense)
# print(SyncedLayers().BatchNormalization)
# Out:
# [stdout:0]
# <class 'tensorflow.python.keras.layers.core.Dense'>
# <class 'horovod.tensorflow.sync_batch_norm.SyncBatchNormalization'>
# [stdout:1]
# <class 'tensorflow.python.keras.layers.core.Dense'>
# <class 'horovod.tensorflow.sync_batch_norm.SyncBatchNormalization'>

# %%
# %%px
# from resnet_v2 import ResNet50V2
# model = ResNet50V2(include_top=True, classes=1000, weights=None)
# # model = ResNet50V2(include_top=True, classes=1000, weights=None, layers=SyncedLayers())
#
# lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
#     initial_learning_rate=lr,
#     alpha=0.01,
#     decay_steps=steps_per_epoch*epochs
# )
#
# optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)
# optimizer = hvd.DistributedOptimizer(optimizer)
#
# model.compile(optimizer=optimizer,
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy',
#                        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="Top5")])
#
# callbacks = [
#     # Horovod: average metrics among workers at the end of every epoch.
#     # Note: This callback must be in the list before the ReduceLROnPlateau,
#     # TensorBoard or other metrics-based callbacks.
#     hvd.callbacks.MetricAverageCallback(),
#
#     # Horovod: broadcast initial variable states from rank 0 to all other processes.
#     # This is necessary to ensure consistent initialization of all workers when
#     # training is started with random weights or restored from a checkpoint.
#     hvd.callbacks.BroadcastGlobalVariablesCallback(0),
#
# #     tf.keras.callbacks.TensorBoard(
# #         log_dir=os.path.join(os.environ['SCRATCH'], 'imagenet_logs', datetime.now().strftime("%y%m%d-%H%M")),
# #         histogram_freq=1,
# # #         profile_batch='80,100',
# #         update_freq=100, # batches
# #     )
# ]
# Out:
# [stderr:0]
# /apps/daint/UES/6.0.UP04/sandboxes/sarafael/mc-sumsch-2021/lib/python3.7/site-packages/horovod/_keras/callbacks.py:59: UserWarning: Some callbacks may not have access to the averaged metrics, see https://github.com/horovod/horovod/issues/2440
#   "Some callbacks may not have access to the averaged metrics, "
# [stderr:1]
# /apps/daint/UES/6.0.UP04/sandboxes/sarafael/mc-sumsch-2021/lib/python3.7/site-packages/horovod/_keras/callbacks.py:59: UserWarning: Some callbacks may not have access to the averaged metrics, see https://github.com/horovod/horovod/issues/2440
#   "Some callbacks may not have access to the averaged metrics, "

# %%
# %reload_ext tensorboard

# imagenet_logs = os.path.join(os.environ['SCRATCH'], 'imagenet_logs')
# %tensorboard --logdir={imagenet_logs}

# %%
# %%px --noblock -o training
# # the non-blocking execution (`%%px --noblock`) returns an `AsyncResult` object inmediately.
# # the `AsyncResult` object can be accessed from python with the option `-o <variable>`.
# # by doing that we can fetch information while the code running.
#
# fit = model.fit(
#     train_ds,
#     steps_per_epoch=17, #steps_per_epoch,
# #     validation_data=valid_ds,
# #     validation_steps=validation_steps,
#     epochs=1, #epochs,
#     callbacks=[callbacks],
#     verbose=1 if hvd.rank() == 0 else 0,  # use verbose=2 in a production script (sbatch)
# )
# Out:
# <AsyncResult: execute>

# %%
# watch the output in real time
utilities.watch_asyncresult(training)
# Out:
# [ stdout 0 ]
# 17/17 [==============================] - 31s 759ms/step - loss: 7.2460 - accuracy: 4.5956e-04 - Top5: 0.0041

# %%
# %%px
# fit.history
# Out:
# Out[0:8]: {'loss': [7.2450957], 'accuracy': [0.0020680148], 'Top5': [0.005744485]}
# Out[1:8]: {'loss': [7.2450957], 'accuracy': [0.0020680148], 'Top5': [0.005744485]}

# %%
# %%px
# ## Average and calculate MAE of all 1 dimensional weights
# norms = {w.name : np.mean(abs(w - hvd.allreduce(w))) for w in model.weights if len(w.shape) == 1}
# norms
# Out:
# Out[0:9]:
# {'conv1_conv/bias:0': 0.0,
#  'conv2_block1_preact_bn/gamma:0': 0.0,
#  'conv2_block1_preact_bn/beta:0': 0.0,
#  'conv2_block1_preact_bn/moving_mean:0': 0.013615761,
#  'conv2_block1_preact_bn/moving_variance:0': 0.6237906,
#  'conv2_block1_1_bn/gamma:0': 0.0,
#  'conv2_block1_1_bn/beta:0': 0.0,
#  'conv2_block1_1_bn/moving_mean:0': 5.103124e-05,
#  'conv2_block1_1_bn/moving_variance:0': 0.0004121717,
#  'conv2_block1_2_bn/gamma:0': 0.0,
#  'conv2_block1_2_bn/beta:0': 0.0,
#  'conv2_block1_2_bn/moving_mean:0': 0.00019584777,
#  'conv2_block1_2_bn/moving_variance:0': 0.0028897244,
#  'conv2_block1_0_conv/bias:0': 0.0,
#  'conv2_block1_3_conv/bias:0': 0.0,
#  'conv2_block2_preact_bn/gamma:0': 0.0,
#  'conv2_block2_preact_bn/beta:0': 0.0,
#  'conv2_block2_preact_bn/moving_mean:0': 4.247424e-05,
#  'conv2_block2_preact_bn/moving_variance:0': 0.00022370974,
#  'conv2_block2_1_bn/gamma:0': 0.0,
#  'conv2_block2_1_bn/beta:0': 0.0,
#  'conv2_block2_1_bn/moving_mean:0': 6.1986735e-05,
#  'conv2_block2_1_bn/moving_variance:0': 0.00049230456,
#  'conv2_block2_2_bn/gamma:0': 0.0,
#  'conv2_block2_2_bn/beta:0': 0.0,
#  'conv2_block2_2_bn/moving_mean:0': 7.446994e-05,
#  'conv2_block2_2_bn/moving_variance:0': 0.0010875557,
#  'conv2_block2_3_conv/bias:0': 0.0,
#  'conv2_block3_preact_bn/gamma:0': 0.0,
#  'conv2_block3_preact_bn/beta:0': 0.0,
#  'conv2_block3_preact_bn/moving_mean:0': 5.6760815e-05,
#  'conv2_block3_preact_bn/moving_variance:0': 0.00030202908,
#  'conv2_block3_1_bn/gamma:0': 0.0,
#  'conv2_block3_1_bn/beta:0': 0.0,
#  'conv2_block3_1_bn/moving_mean:0': 5.6410838e-05,
#  'conv2_block3_1_bn/moving_variance:0': 0.00034074206,
#  'conv2_block3_2_bn/gamma:0': 0.0,
#  'conv2_block3_2_bn/beta:0': 0.0,
#  'conv2_block3_2_bn/moving_mean:0': 5.9628408e-05,
#  'conv2_block3_2_bn/moving_variance:0': 0.0005203029,
#  'conv2_block3_3_conv/bias:0': 0.0,
#  'conv3_block1_preact_bn/gamma:0': 0.0,
#  'conv3_block1_preact_bn/beta:0': 0.0,
#  'conv3_block1_preact_bn/moving_mean:0': 6.4527834e-05,
#  'conv3_block1_preact_bn/moving_variance:0': 0.00036441698,
#  'conv3_block1_1_bn/gamma:0': 0.0,
#  'conv3_block1_1_bn/beta:0': 0.0,
#  'conv3_block1_1_bn/moving_mean:0': 5.6835197e-05,
#  'conv3_block1_1_bn/moving_variance:0': 0.00020031957,
#  'conv3_block1_2_bn/gamma:0': 0.0,
#  'conv3_block1_2_bn/beta:0': 0.0,
#  'conv3_block1_2_bn/moving_mean:0': 7.5823846e-05,
#  'conv3_block1_2_bn/moving_variance:0': 0.00070809294,
#  'conv3_block1_0_conv/bias:0': 0.0,
#  'conv3_block1_3_conv/bias:0': 0.0,
#  'conv3_block2_preact_bn/gamma:0': 0.0,
#  'conv3_block2_preact_bn/beta:0': 0.0,
#  'conv3_block2_preact_bn/moving_mean:0': 5.2098636e-05,
#  'conv3_block2_preact_bn/moving_variance:0': 0.00020901009,
#  'conv3_block2_1_bn/gamma:0': 0.0,
#  'conv3_block2_1_bn/beta:0': 0.0,
#  'conv3_block2_1_bn/moving_mean:0': 6.829809e-05,
#  'conv3_block2_1_bn/moving_variance:0': 0.00035716454,
#  'conv3_block2_2_bn/gamma:0': 0.0,
#  'conv3_block2_2_bn/beta:0': 0.0,
#  'conv3_block2_2_bn/moving_mean:0': 6.495798e-05,
#  'conv3_block2_2_bn/moving_variance:0': 0.00035122875,
#  'conv3_block2_3_conv/bias:0': 0.0,
#  'conv3_block3_preact_bn/gamma:0': 0.0,
#  'conv3_block3_preact_bn/beta:0': 0.0,
#  'conv3_block3_preact_bn/moving_mean:0': 6.49044e-05,
#  'conv3_block3_preact_bn/moving_variance:0': 0.0003192192,
#  'conv3_block3_1_bn/gamma:0': 0.0,
#  'conv3_block3_1_bn/beta:0': 0.0,
#  'conv3_block3_1_bn/moving_mean:0': 6.673808e-05,
#  'conv3_block3_1_bn/moving_variance:0': 0.0003431742,
#  'conv3_block3_2_bn/gamma:0': 0.0,
#  'conv3_block3_2_bn/beta:0': 0.0,
#  'conv3_block3_2_bn/moving_mean:0': 5.256608e-05,
#  'conv3_block3_2_bn/moving_variance:0': 0.00030226354,
#  'conv3_block3_3_conv/bias:0': 0.0,
#  'conv3_block4_preact_bn/gamma:0': 0.0,
#  'conv3_block4_preact_bn/beta:0': 0.0,
#  'conv3_block4_preact_bn/moving_mean:0': 7.263951e-05,
#  'conv3_block4_preact_bn/moving_variance:0': 0.0003981199,
#  'conv3_block4_1_bn/gamma:0': 0.0,
#  'conv3_block4_1_bn/beta:0': 0.0,
#  'conv3_block4_1_bn/moving_mean:0': 7.19295e-05,
#  'conv3_block4_1_bn/moving_variance:0': 0.00028762035,
#  'conv3_block4_2_bn/gamma:0': 0.0,
#  'conv3_block4_2_bn/beta:0': 0.0,
#  'conv3_block4_2_bn/moving_mean:0': 6.535108e-05,
#  'conv3_block4_2_bn/moving_variance:0': 0.00027230056,
#  'conv3_block4_3_conv/bias:0': 0.0,
#  'conv4_block1_preact_bn/gamma:0': 0.0,
#  'conv4_block1_preact_bn/beta:0': 0.0,
#  'conv4_block1_preact_bn/moving_mean:0': 9.265136e-05,
#  'conv4_block1_preact_bn/moving_variance:0': 0.0004799593,
#  'conv4_block1_1_bn/gamma:0': 0.0,
#  'conv4_block1_1_bn/beta:0': 0.0,
#  'conv4_block1_1_bn/moving_mean:0': 6.16022e-05,
#  'conv4_block1_1_bn/moving_variance:0': 0.00022684666,
#  'conv4_block1_2_bn/gamma:0': 0.0,
#  'conv4_block1_2_bn/beta:0': 0.0,
#  'conv4_block1_2_bn/moving_mean:0': 6.2260646e-05,
#  'conv4_block1_2_bn/moving_variance:0': 0.0004056662,
#  'conv4_block1_0_conv/bias:0': 0.0,
#  'conv4_block1_3_conv/bias:0': 0.0,
#  'conv4_block2_preact_bn/gamma:0': 0.0,
#  'conv4_block2_preact_bn/beta:0': 0.0,
#  'conv4_block2_preact_bn/moving_mean:0': 5.4395212e-05,
#  'conv4_block2_preact_bn/moving_variance:0': 0.00020221237,
#  'conv4_block2_1_bn/gamma:0': 0.0,
#  'conv4_block2_1_bn/beta:0': 0.0,
#  'conv4_block2_1_bn/moving_mean:0': 6.7474655e-05,
#  'conv4_block2_1_bn/moving_variance:0': 0.0002827819,
#  'conv4_block2_2_bn/gamma:0': 0.0,
#  'conv4_block2_2_bn/beta:0': 0.0,
#  'conv4_block2_2_bn/moving_mean:0': 6.583304e-05,
#  'conv4_block2_2_bn/moving_variance:0': 0.0002862406,
#  'conv4_block2_3_conv/bias:0': 0.0,
#  'conv4_block3_preact_bn/gamma:0': 0.0,
#  'conv4_block3_preact_bn/beta:0': 0.0,
#  'conv4_block3_preact_bn/moving_mean:0': 6.5581444e-05,
#  'conv4_block3_preact_bn/moving_variance:0': 0.00029493717,
#  'conv4_block3_1_bn/gamma:0': 0.0,
#  'conv4_block3_1_bn/beta:0': 0.0,
#  'conv4_block3_1_bn/moving_mean:0': 6.885401e-05,
#  'conv4_block3_1_bn/moving_variance:0': 0.00033235014,
#  'conv4_block3_2_bn/gamma:0': 0.0,
#  'conv4_block3_2_bn/beta:0': 0.0,
#  'conv4_block3_2_bn/moving_mean:0': 6.507727e-05,
#  'conv4_block3_2_bn/moving_variance:0': 0.0002677096,
#  'conv4_block3_3_conv/bias:0': 0.0,
#  'conv4_block4_preact_bn/gamma:0': 0.0,
#  'conv4_block4_preact_bn/beta:0': 0.0,
#  'conv4_block4_preact_bn/moving_mean:0': 8.260577e-05,
#  'conv4_block4_preact_bn/moving_variance:0': 0.00040140492,
#  'conv4_block4_1_bn/gamma:0': 0.0,
#  'conv4_block4_1_bn/beta:0': 0.0,
#  'conv4_block4_1_bn/moving_mean:0': 7.711582e-05,
#  'conv4_block4_1_bn/moving_variance:0': 0.00032477616,
#  'conv4_block4_2_bn/gamma:0': 0.0,
#  'conv4_block4_2_bn/beta:0': 0.0,
#  'conv4_block4_2_bn/moving_mean:0': 7.351699e-05,
#  'conv4_block4_2_bn/moving_variance:0': 0.00033983332,
#  'conv4_block4_3_conv/bias:0': 0.0,
#  'conv4_block5_preact_bn/gamma:0': 0.0,
#  'conv4_block5_preact_bn/beta:0': 0.0,
#  'conv4_block5_preact_bn/moving_mean:0': 0.00010301481,
#  'conv4_block5_preact_bn/moving_variance:0': 0.00054054905,
#  'conv4_block5_1_bn/gamma:0': 0.0,
#  'conv4_block5_1_bn/beta:0': 0.0,
#  'conv4_block5_1_bn/moving_mean:0': 8.9589674e-05,
#  'conv4_block5_1_bn/moving_variance:0': 0.00039200112,
#  'conv4_block5_2_bn/gamma:0': 0.0,
#  'conv4_block5_2_bn/beta:0': 0.0,
#  'conv4_block5_2_bn/moving_mean:0': 8.285137e-05,
#  'conv4_block5_2_bn/moving_variance:0': 0.00035913428,
#  'conv4_block5_3_conv/bias:0': 0.0,
#  'conv4_block6_preact_bn/gamma:0': 0.0,
#  'conv4_block6_preact_bn/beta:0': 0.0,
#  'conv4_block6_preact_bn/moving_mean:0': 0.00011676886,
#  'conv4_block6_preact_bn/moving_variance:0': 0.0006582513,
#  'conv4_block6_1_bn/gamma:0': 0.0,
#  'conv4_block6_1_bn/beta:0': 0.0,
#  'conv4_block6_1_bn/moving_mean:0': 9.250711e-05,
#  'conv4_block6_1_bn/moving_variance:0': 0.0003515149,
#  'conv4_block6_2_bn/gamma:0': 0.0,
#  'conv4_block6_2_bn/beta:0': 0.0,
#  'conv4_block6_2_bn/moving_mean:0': 0.00013274993,
#  'conv4_block6_2_bn/moving_variance:0': 0.0003549275,
#  'conv4_block6_3_conv/bias:0': 0.0,
#  'conv5_block1_preact_bn/gamma:0': 0.0,
#  'conv5_block1_preact_bn/beta:0': 0.0,
#  'conv5_block1_preact_bn/moving_mean:0': 0.00020770624,
#  'conv5_block1_preact_bn/moving_variance:0': 0.0009358681,
#  'conv5_block1_1_bn/gamma:0': 0.0,
#  'conv5_block1_1_bn/beta:0': 0.0,
#  'conv5_block1_1_bn/moving_mean:0': 0.00011104043,
#  'conv5_block1_1_bn/moving_variance:0': 0.0003882466,
#  'conv5_block1_2_bn/gamma:0': 0.0,
#  'conv5_block1_2_bn/beta:0': 0.0,
#  'conv5_block1_2_bn/moving_mean:0': 0.00011983702,
#  'conv5_block1_2_bn/moving_variance:0': 0.0005329775,
#  'conv5_block1_0_conv/bias:0': 0.0,
#  'conv5_block1_3_conv/bias:0': 0.0,
#  'conv5_block2_preact_bn/gamma:0': 0.0,
#  'conv5_block2_preact_bn/beta:0': 0.0,
#  'conv5_block2_preact_bn/moving_mean:0': 0.00010736614,
#  'conv5_block2_preact_bn/moving_variance:0': 0.00036064643,
#  'conv5_block2_1_bn/gamma:0': 0.0,
#  'conv5_block2_1_bn/beta:0': 0.0,
#  'conv5_block2_1_bn/moving_mean:0': 0.00013113272,
#  'conv5_block2_1_bn/moving_variance:0': 0.00050165586,
#  'conv5_block2_2_bn/gamma:0': 0.0,
#  'conv5_block2_2_bn/beta:0': 0.0,
#  'conv5_block2_2_bn/moving_mean:0': 0.00012864906,
#  'conv5_block2_2_bn/moving_variance:0': 0.00041706115,
#  'conv5_block2_3_conv/bias:0': 0.0,
#  'conv5_block3_preact_bn/gamma:0': 0.0,
#  'conv5_block3_preact_bn/beta:0': 0.0,
#  'conv5_block3_preact_bn/moving_mean:0': 0.00013297595,
#  'conv5_block3_preact_bn/moving_variance:0': 0.00052208384,
#  'conv5_block3_1_bn/gamma:0': 0.0,
#  'conv5_block3_1_bn/beta:0': 0.0,
#  'conv5_block3_1_bn/moving_mean:0': 0.00013910305,
#  'conv5_block3_1_bn/moving_variance:0': 0.0004068698,
#  'conv5_block3_2_bn/gamma:0': 0.0,
#  'conv5_block3_2_bn/beta:0': 0.0,
#  'conv5_block3_2_bn/moving_mean:0': 0.00012128269,
#  'conv5_block3_2_bn/moving_variance:0': 0.00039310288,
#  'conv5_block3_3_conv/bias:0': 0.0,
#  'post_bn/gamma:0': 0.0,
#  'post_bn/beta:0': 0.0,
#  'post_bn/moving_mean:0': 0.00015398511,
#  'post_bn/moving_variance:0': 0.0007355006,
#  'predictions/bias:0': 0.0}
# Out[1:9]:
# {'conv1_conv/bias:0': 0.0,
#  'conv2_block1_preact_bn/gamma:0': 0.0,
#  'conv2_block1_preact_bn/beta:0': 0.0,
#  'conv2_block1_preact_bn/moving_mean:0': 0.013615759,
#  'conv2_block1_preact_bn/moving_variance:0': 0.623791,
#  'conv2_block1_1_bn/gamma:0': 0.0,
#  'conv2_block1_1_bn/beta:0': 0.0,
#  'conv2_block1_1_bn/moving_mean:0': 5.1030613e-05,
#  'conv2_block1_1_bn/moving_variance:0': 0.00041217916,
#  'conv2_block1_2_bn/gamma:0': 0.0,
#  'conv2_block1_2_bn/beta:0': 0.0,
#  'conv2_block1_2_bn/moving_mean:0': 0.000195846,
#  'conv2_block1_2_bn/moving_variance:0': 0.00288973,
#  'conv2_block1_0_conv/bias:0': 0.0,
#  'conv2_block1_3_conv/bias:0': 0.0,
#  'conv2_block2_preact_bn/gamma:0': 0.0,
#  'conv2_block2_preact_bn/beta:0': 0.0,
#  'conv2_block2_preact_bn/moving_mean:0': 4.247419e-05,
#  'conv2_block2_preact_bn/moving_variance:0': 0.0002237081,
#  'conv2_block2_1_bn/gamma:0': 0.0,
#  'conv2_block2_1_bn/beta:0': 0.0,
#  'conv2_block2_1_bn/moving_mean:0': 6.198883e-05,
#  'conv2_block2_1_bn/moving_variance:0': 0.000492312,
#  'conv2_block2_2_bn/gamma:0': 0.0,
#  'conv2_block2_2_bn/beta:0': 0.0,
#  'conv2_block2_2_bn/moving_mean:0': 7.446878e-05,
#  'conv2_block2_2_bn/moving_variance:0': 0.0010875566,
#  'conv2_block2_3_conv/bias:0': 0.0,
#  'conv2_block3_preact_bn/gamma:0': 0.0,
#  'conv2_block3_preact_bn/beta:0': 0.0,
#  'conv2_block3_preact_bn/moving_mean:0': 5.6761157e-05,
#  'conv2_block3_preact_bn/moving_variance:0': 0.0003020293,
#  'conv2_block3_1_bn/gamma:0': 0.0,
#  'conv2_block3_1_bn/beta:0': 0.0,
#  'conv2_block3_1_bn/moving_mean:0': 5.641051e-05,
#  'conv2_block3_1_bn/moving_variance:0': 0.00034073647,
#  'conv2_block3_2_bn/gamma:0': 0.0,
#  'conv2_block3_2_bn/beta:0': 0.0,
#  'conv2_block3_2_bn/moving_mean:0': 5.9628685e-05,
#  'conv2_block3_2_bn/moving_variance:0': 0.00052030757,
#  'conv2_block3_3_conv/bias:0': 0.0,
#  'conv3_block1_preact_bn/gamma:0': 0.0,
#  'conv3_block1_preact_bn/beta:0': 0.0,
#  'conv3_block1_preact_bn/moving_mean:0': 6.4528285e-05,
#  'conv3_block1_preact_bn/moving_variance:0': 0.0003644193,
#  'conv3_block1_1_bn/gamma:0': 0.0,
#  'conv3_block1_1_bn/beta:0': 0.0,
#  'conv3_block1_1_bn/moving_mean:0': 5.6835728e-05,
#  'conv3_block1_1_bn/moving_variance:0': 0.00020032097,
#  'conv3_block1_2_bn/gamma:0': 0.0,
#  'conv3_block1_2_bn/beta:0': 0.0,
#  'conv3_block1_2_bn/moving_mean:0': 7.582316e-05,
#  'conv3_block1_2_bn/moving_variance:0': 0.0007081027,
#  'conv3_block1_0_conv/bias:0': 0.0,
#  'conv3_block1_3_conv/bias:0': 0.0,
#  'conv3_block2_preact_bn/gamma:0': 0.0,
#  'conv3_block2_preact_bn/beta:0': 0.0,
#  'conv3_block2_preact_bn/moving_mean:0': 5.209849e-05,
#  'conv3_block2_preact_bn/moving_variance:0': 0.00020901184,
#  'conv3_block2_1_bn/gamma:0': 0.0,
#  'conv3_block2_1_bn/beta:0': 0.0,
#  'conv3_block2_1_bn/moving_mean:0': 6.82978e-05,
#  'conv3_block2_1_bn/moving_variance:0': 0.0003571664,
#  'conv3_block2_2_bn/gamma:0': 0.0,
#  'conv3_block2_2_bn/beta:0': 0.0,
#  'conv3_block2_2_bn/moving_mean:0': 6.495873e-05,
#  'conv3_block2_2_bn/moving_variance:0': 0.00035122782,
#  'conv3_block2_3_conv/bias:0': 0.0,
#  'conv3_block3_preact_bn/gamma:0': 0.0,
#  'conv3_block3_preact_bn/beta:0': 0.0,
#  'conv3_block3_preact_bn/moving_mean:0': 6.490419e-05,
#  'conv3_block3_preact_bn/moving_variance:0': 0.00031921826,
#  'conv3_block3_1_bn/gamma:0': 0.0,
#  'conv3_block3_1_bn/beta:0': 0.0,
#  'conv3_block3_1_bn/moving_mean:0': 6.673797e-05,
#  'conv3_block3_1_bn/moving_variance:0': 0.0003431756,
#  'conv3_block3_2_bn/gamma:0': 0.0,
#  'conv3_block3_2_bn/beta:0': 0.0,
#  'conv3_block3_2_bn/moving_mean:0': 5.2566065e-05,
#  'conv3_block3_2_bn/moving_variance:0': 0.00030226354,
#  'conv3_block3_3_conv/bias:0': 0.0,
#  'conv3_block4_preact_bn/gamma:0': 0.0,
#  'conv3_block4_preact_bn/beta:0': 0.0,
#  'conv3_block4_preact_bn/moving_mean:0': 7.263961e-05,
#  'conv3_block4_preact_bn/moving_variance:0': 0.0003981198,
#  'conv3_block4_1_bn/gamma:0': 0.0,
#  'conv3_block4_1_bn/beta:0': 0.0,
#  'conv3_block4_1_bn/moving_mean:0': 7.192994e-05,
#  'conv3_block4_1_bn/moving_variance:0': 0.00028761616,
#  'conv3_block4_2_bn/gamma:0': 0.0,
#  'conv3_block4_2_bn/beta:0': 0.0,
#  'conv3_block4_2_bn/moving_mean:0': 6.535069e-05,
#  'conv3_block4_2_bn/moving_variance:0': 0.0002723015,
#  'conv3_block4_3_conv/bias:0': 0.0,
#  'conv4_block1_preact_bn/gamma:0': 0.0,
#  'conv4_block1_preact_bn/beta:0': 0.0,
#  'conv4_block1_preact_bn/moving_mean:0': 9.26511e-05,
#  'conv4_block1_preact_bn/moving_variance:0': 0.00047996175,
#  'conv4_block1_1_bn/gamma:0': 0.0,
#  'conv4_block1_1_bn/beta:0': 0.0,
#  'conv4_block1_1_bn/moving_mean:0': 6.1602266e-05,
#  'conv4_block1_1_bn/moving_variance:0': 0.00022684503,
#  'conv4_block1_2_bn/gamma:0': 0.0,
#  'conv4_block1_2_bn/beta:0': 0.0,
#  'conv4_block1_2_bn/moving_mean:0': 6.226085e-05,
#  'conv4_block1_2_bn/moving_variance:0': 0.00040567177,
#  'conv4_block1_0_conv/bias:0': 0.0,
#  'conv4_block1_3_conv/bias:0': 0.0,
#  'conv4_block2_preact_bn/gamma:0': 0.0,
#  'conv4_block2_preact_bn/beta:0': 0.0,
#  'conv4_block2_preact_bn/moving_mean:0': 5.4395186e-05,
#  'conv4_block2_preact_bn/moving_variance:0': 0.00020221248,
#  'conv4_block2_1_bn/gamma:0': 0.0,
#  'conv4_block2_1_bn/beta:0': 0.0,
#  'conv4_block2_1_bn/moving_mean:0': 6.7475106e-05,
#  'conv4_block2_1_bn/moving_variance:0': 0.00028278446,
#  'conv4_block2_2_bn/gamma:0': 0.0,
#  'conv4_block2_2_bn/beta:0': 0.0,
#  'conv4_block2_2_bn/moving_mean:0': 6.583294e-05,
#  'conv4_block2_2_bn/moving_variance:0': 0.00028624106,
#  'conv4_block2_3_conv/bias:0': 0.0,
#  'conv4_block3_preact_bn/gamma:0': 0.0,
#  'conv4_block3_preact_bn/beta:0': 0.0,
#  'conv4_block3_preact_bn/moving_mean:0': 6.558156e-05,
#  'conv4_block3_preact_bn/moving_variance:0': 0.00029493344,
#  'conv4_block3_1_bn/gamma:0': 0.0,
#  'conv4_block3_1_bn/beta:0': 0.0,
#  'conv4_block3_1_bn/moving_mean:0': 6.885462e-05,
#  'conv4_block3_1_bn/moving_variance:0': 0.00033234805,
#  'conv4_block3_2_bn/gamma:0': 0.0,
#  'conv4_block3_2_bn/beta:0': 0.0,
#  'conv4_block3_2_bn/moving_mean:0': 6.5077475e-05,
#  'conv4_block3_2_bn/moving_variance:0': 0.00026770844,
#  'conv4_block3_3_conv/bias:0': 0.0,
#  'conv4_block4_preact_bn/gamma:0': 0.0,
#  'conv4_block4_preact_bn/beta:0': 0.0,
#  'conv4_block4_preact_bn/moving_mean:0': 8.2605664e-05,
#  'conv4_block4_preact_bn/moving_variance:0': 0.00040140608,
#  'conv4_block4_1_bn/gamma:0': 0.0,
#  'conv4_block4_1_bn/beta:0': 0.0,
#  'conv4_block4_1_bn/moving_mean:0': 7.711525e-05,
#  'conv4_block4_1_bn/moving_variance:0': 0.0003247764,
#  'conv4_block4_2_bn/gamma:0': 0.0,
#  'conv4_block4_2_bn/beta:0': 0.0,
#  'conv4_block4_2_bn/moving_mean:0': 7.351684e-05,
#  'conv4_block4_2_bn/moving_variance:0': 0.00033983472,
#  'conv4_block4_3_conv/bias:0': 0.0,
#  'conv4_block5_preact_bn/gamma:0': 0.0,
#  'conv4_block5_preact_bn/beta:0': 0.0,
#  'conv4_block5_preact_bn/moving_mean:0': 0.00010301497,
#  'conv4_block5_preact_bn/moving_variance:0': 0.0005405497,
#  'conv4_block5_1_bn/gamma:0': 0.0,
#  'conv4_block5_1_bn/beta:0': 0.0,
#  'conv4_block5_1_bn/moving_mean:0': 8.958977e-05,
#  'conv4_block5_1_bn/moving_variance:0': 0.00039200555,
#  'conv4_block5_2_bn/gamma:0': 0.0,
#  'conv4_block5_2_bn/beta:0': 0.0,
#  'conv4_block5_2_bn/moving_mean:0': 8.285135e-05,
#  'conv4_block5_2_bn/moving_variance:0': 0.00035913032,
#  'conv4_block5_3_conv/bias:0': 0.0,
#  'conv4_block6_preact_bn/gamma:0': 0.0,
#  'conv4_block6_preact_bn/beta:0': 0.0,
#  'conv4_block6_preact_bn/moving_mean:0': 0.00011676906,
#  'conv4_block6_preact_bn/moving_variance:0': 0.00065825,
#  'conv4_block6_1_bn/gamma:0': 0.0,
#  'conv4_block6_1_bn/beta:0': 0.0,
#  'conv4_block6_1_bn/moving_mean:0': 9.250654e-05,
#  'conv4_block6_1_bn/moving_variance:0': 0.00035151723,
#  'conv4_block6_2_bn/gamma:0': 0.0,
#  'conv4_block6_2_bn/beta:0': 0.0,
#  'conv4_block6_2_bn/moving_mean:0': 0.00013274941,
#  'conv4_block6_2_bn/moving_variance:0': 0.0003549282,
#  'conv4_block6_3_conv/bias:0': 0.0,
#  'conv5_block1_preact_bn/gamma:0': 0.0,
#  'conv5_block1_preact_bn/beta:0': 0.0,
#  'conv5_block1_preact_bn/moving_mean:0': 0.00020770641,
#  'conv5_block1_preact_bn/moving_variance:0': 0.0009358713,
#  'conv5_block1_1_bn/gamma:0': 0.0,
#  'conv5_block1_1_bn/beta:0': 0.0,
#  'conv5_block1_1_bn/moving_mean:0': 0.0001110403,
#  'conv5_block1_1_bn/moving_variance:0': 0.0003882472,
#  'conv5_block1_2_bn/gamma:0': 0.0,
#  'conv5_block1_2_bn/beta:0': 0.0,
#  'conv5_block1_2_bn/moving_mean:0': 0.00011983678,
#  'conv5_block1_2_bn/moving_variance:0': 0.00053297635,
#  'conv5_block1_0_conv/bias:0': 0.0,
#  'conv5_block1_3_conv/bias:0': 0.0,
#  'conv5_block2_preact_bn/gamma:0': 0.0,
#  'conv5_block2_preact_bn/beta:0': 0.0,
#  'conv5_block2_preact_bn/moving_mean:0': 0.00010736608,
#  'conv5_block2_preact_bn/moving_variance:0': 0.00036064812,
#  'conv5_block2_1_bn/gamma:0': 0.0,
#  'conv5_block2_1_bn/beta:0': 0.0,
#  'conv5_block2_1_bn/moving_mean:0': 0.00013113295,
#  'conv5_block2_1_bn/moving_variance:0': 0.00050165504,
#  'conv5_block2_2_bn/gamma:0': 0.0,
#  'conv5_block2_2_bn/beta:0': 0.0,
#  'conv5_block2_2_bn/moving_mean:0': 0.00012864903,
#  'conv5_block2_2_bn/moving_variance:0': 0.00041705882,
#  'conv5_block2_3_conv/bias:0': 0.0,
#  'conv5_block3_preact_bn/gamma:0': 0.0,
#  'conv5_block3_preact_bn/beta:0': 0.0,
#  'conv5_block3_preact_bn/moving_mean:0': 0.00013297575,
#  'conv5_block3_preact_bn/moving_variance:0': 0.00052208547,
#  'conv5_block3_1_bn/gamma:0': 0.0,
#  'conv5_block3_1_bn/beta:0': 0.0,
#  'conv5_block3_1_bn/moving_mean:0': 0.0001391035,
#  'conv5_block3_1_bn/moving_variance:0': 0.00040687132,
#  'conv5_block3_2_bn/gamma:0': 0.0,
#  'conv5_block3_2_bn/beta:0': 0.0,
#  'conv5_block3_2_bn/moving_mean:0': 0.00012128271,
#  'conv5_block3_2_bn/moving_variance:0': 0.00039310113,
#  'conv5_block3_3_conv/bias:0': 0.0,
#  'post_bn/gamma:0': 0.0,
#  'post_bn/beta:0': 0.0,
#  'post_bn/moving_mean:0': 0.00015398502,
#  'post_bn/moving_variance:0': 0.0007354978,
#  'predictions/bias:0': 0.0}

# %%
# %ipcluster stop
