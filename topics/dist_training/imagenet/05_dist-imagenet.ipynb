# %%
import os
import ipcmagic
from ipcmagic import utilities
# %ipcluster start -n {int(os.environ['SLURM_NNODES'])} --mpi
# Out:
# IPCluster is ready! (6 seconds)

# %%
# %%px
# import os
# import math
# import glob
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# import tensorflow as tf
# import tensorflow_addons as tfa
# import albumentations as alb
# import horovod.tensorflow.keras as hvd
#
# AUTO = tf.data.experimental.AUTOTUNE
#
# epochs = 1 #50
# batch_size = 128
# valid_samples, train_samples = 50000, 1281167
#
# hvd.init()
#
# num_nodes, node_id = hvd.size(), hvd.rank()
# cache_train = (num_nodes >= 4)
#
# ## Large Batch Optimization for Deep Learning https://arxiv.org/abs/1904.00962 (tfa.optimizers.LAMB)
# ## - square root LR scaling
# lr = 0.1 * num_nodes**0.5
#
# global_batch_size = (batch_size * num_nodes)
# validation_steps = math.ceil(valid_samples / global_batch_size)
# steps_per_epoch = round(train_samples / global_batch_size)
#
# print(num_nodes, node_id, cache_train, lr, validation_steps, steps_per_epoch)
# Out:
# [stdout:0] 2 0 False 0.2 196 5005
# [stdout:1] 2 1 False 0.2 196 5005

# %%
# %%px
# train_files = sorted(glob.glob('/scratch/snx3000/datasets/imagenet/ILSVRC2012_1k/train/*'))
# valid_files = sorted(glob.glob('/scratch/snx3000/datasets/imagenet/ILSVRC2012_1k/validation/*'))
# print(len(train_files), len(valid_files))
# Out:
# [stdout:0] 1024 128
# [stdout:1] 1024 128

# %%
# %%px
# image_shape = (224, 224)
#
# def process_image(serialized_example, transforms):
#     ''' decode and augment images '''
#     features = tf.io.parse_single_example(
#         serialized_example,
#         features={
#             'image/encoded': tf.io.FixedLenFeature([], tf.string),
#             'image/class/label': tf.io.FixedLenFeature([], tf.int64),
#         })
#     image = tf.image.decode_jpeg(features['image/encoded'], channels=3)
#     label = tf.cast(features['image/class/label'], tf.int64) - 1  # [0-999]
#
#     image_aug = lambda img: transforms(image=img)["image"]
#     aug_img = tf.numpy_function(func=image_aug, inp=[image], Tout=tf.float32)
#     return aug_img, label
#
#
# train_transforms = alb.Compose([
#             alb.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=30),
#             alb.HorizontalFlip(p=0.5),
#             alb.OneOf([ # Add or remove noise
#                 alb.GaussNoise(var_limit=(50, 200)),
#                 alb.ImageCompression(quality_lower=80, quality_upper=95),
#                 alb.GaussianBlur(sigma_limit=(2, 10)),
#             ], p=1),
#             alb.SomeOf([ # Color ops
#                 alb.ToGray(p=0.1),
#                 alb.Equalize(by_channels=False),
#                 alb.RGBShift(r_shift_limit=10, g_shift_limit=10, b_shift_limit=10),
#                 alb.RandomGamma(gamma_limit=(90, 110)),
#                 alb.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=10, val_shift_limit=10),
#                 alb.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.2, 0.2)),
#             ], n=2),
#             alb.RandomResizedCrop(*image_shape, scale=(0.9, 1.1), ratio=(0.9, 1.1)),
#             alb.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#         ])
#
# valid_transforms = alb.Compose([
#             alb.SmallestMaxSize(max_size=image_shape[0]),
#             alb.CenterCrop(*image_shape),
#             alb.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#         ])

# %%
# %%px
# def get_ds(tfrecords,
#            transforms,
#            batch_size,
#            num_nodes,
#            node_id,
#            seed=42,
#            cache=False,
#            repeat=False,
#            shuffle_buffer=None,
#           ):
#
#     ### TODD: Create your sharded dataset here ###
#     # dataset = ...
#
#     if cache:
#         # caching has to be done before repeat/shuffle
#         dataset = dataset.cache()
#     if repeat:
#         dataset = dataset.repeat()
#     if shuffle_buffer:
#         dataset = dataset.shuffle(buffer_size=shuffle_buffer,
#                                   reshuffle_each_iteration=True,
#                                   seed=seed)
#
#     # decode and augment images
#     decode_aug = lambda img: process_image(img, transforms)
#     dataset = dataset.map(decode_aug, num_parallel_calls=AUTO)
#
#     dataset = dataset.batch(batch_size)
#     dataset = dataset.prefetch(buffer_size=AUTO)
#     return dataset
#
# valid_ds = get_ds(valid_files, valid_transforms, batch_size, num_nodes, node_id, cache=True)
# train_ds = get_ds(train_files, train_transforms, batch_size, num_nodes, node_id,
#                   shuffle_buffer=1024, repeat=True, cache=cache_train)

# %%
# %%px
# model = tf.keras.applications.ResNet50V2(include_top=True, classes=1000, weights=None)
#
# lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
#     initial_learning_rate=lr,
#     alpha=0.01,
#     decay_steps=steps_per_epoch*epochs
# )
#
# optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)
# # optimizer = tfa.optimizers.LAMB(learning_rate=lr_schedule, momentum=0.9)
# optimizer = hvd.DistributedOptimizer(optimizer)
#
# model.compile(optimizer=optimizer,
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy',
#                        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="Top5")])
#
# base_dir = os.path.join(os.environ['SCRATCH'], 'imagenet_runs', datetime.now().strftime("%y%m%d-%H%M"))
#
# callbacks = [
#     # Horovod: average metrics among workers at the end of every epoch.
#     # Note: This callback must be in the list before the ReduceLROnPlateau,
#     # TensorBoard or other metrics-based callbacks.
#     hvd.callbacks.MetricAverageCallback(),
#
#     # Horovod: broadcast initial variable states from rank 0 to all other processes.
#     # This is necessary to ensure consistent initialization of all workers when
#     # training is started with random weights or restored from a checkpoint.
#     hvd.callbacks.BroadcastGlobalVariablesCallback(0),
#
#     tf.keras.callbacks.TensorBoard(
#         log_dir=base_dir,
#         histogram_freq=1,
#         update_freq=100, # batches
#     )
# ]
#
# # Horovod: save checkpoints only on worker 0 to prevent other workers from corrupting them.
# if hvd.rank() == 0:
#     callbacks.append(
#         tf.keras.callbacks.ModelCheckpoint(os.path.join(base_dir, 'checkpoint-{epoch:02d}-{val_accuracy:.03f}.h5'),
#                                            save_weights_only=True,
#                                            save_best_only=True,
#                                            monitor='val_accuracy',
#                                            verbose=1)
#     )
# Out:
# [stderr:0]
# /apps/daint/UES/6.0.UP04/sandboxes/sarafael/mc-sumsch-2021/lib/python3.7/site-packages/horovod/_keras/callbacks.py:59: UserWarning: Some callbacks may not have access to the averaged metrics, see https://github.com/horovod/horovod/issues/2440
#   "Some callbacks may not have access to the averaged metrics, "
# [stderr:1]
# /apps/daint/UES/6.0.UP04/sandboxes/sarafael/mc-sumsch-2021/lib/python3.7/site-packages/horovod/_keras/callbacks.py:59: UserWarning: Some callbacks may not have access to the averaged metrics, see https://github.com/horovod/horovod/issues/2440
#   "Some callbacks may not have access to the averaged metrics, "

# %%
# %reload_ext tensorboard

imagenet_logs = os.path.join(os.environ['SCRATCH'], 'imagenet_runs')
# %tensorboard --logdir={imagenet_logs}

# %%
# %%px --noblock -o training
# # the non-blocking execution (`%%px --noblock`) returns an `AsyncResult` object inmediately.
# # the `AsyncResult` object can be accessed from python with the option `-o <variable>`.
# # by doing that we can fetch information while the code running.
#
# fit = model.fit(
#     train_ds,
#     steps_per_epoch=20, #steps_per_epoch,
#     validation_data=valid_ds,
#     validation_steps=20, #validation_steps,
#     epochs=epochs,
#     callbacks=[callbacks],
#     verbose=1 if hvd.rank() == 0 else 0,  # use verbose=2 in a production script (sbatch)
# )
# Out:
# <AsyncResult: execute>

# %%
# watch the output in real time
utilities.watch_asyncresult(training)
# Out:
# [ stdout 0 ]
# 5005/5005 [==============================] - 3056s 606ms/step - loss: 4.7730 - accuracy: 0.1354 - Top5: 0.2940 - val_loss: 3.3753 - val_accuracy: 0.2922 - val_Top5: 0.5434
#
# Epoch 00001: val_accuracy improved from -inf to 0.29224, saving model to /scratch/snx3000/dealmeih/imagenet_runs/210727-1845/checkpoint-01-0.292.h5

# %% [markdown]
# ### Even though we only synchronize the gradients, all model weights must be equal across all nodes

# %%
# %%px
# ## Average and calculate MAE of all 1 dimensional weights
# norms = {w.name : np.mean(abs(w - hvd.allreduce(w))) for w in model.weights if len(w.shape) == 1}
# norms
# Out:
# Out[0:7]:
# {'conv1_conv/bias:0': 0.0,
#  'conv2_block1_preact_bn/gamma:0': 0.0,
#  'conv2_block1_preact_bn/beta:0': 0.0,
#  'conv2_block1_preact_bn/moving_mean:0': 0.06999695,
#  'conv2_block1_preact_bn/moving_variance:0': 3.9937716,
#  'conv2_block1_1_bn/gamma:0': 0.0,
#  'conv2_block1_1_bn/beta:0': 0.0,
#  'conv2_block1_1_bn/moving_mean:0': 0.0001691964,
#  'conv2_block1_1_bn/moving_variance:0': 0.005263526,
#  'conv2_block1_2_bn/gamma:0': 0.0,
#  'conv2_block1_2_bn/beta:0': 0.0,
#  'conv2_block1_2_bn/moving_mean:0': 0.0018238173,
#  'conv2_block1_2_bn/moving_variance:0': 0.011714559,
#  'conv2_block1_0_conv/bias:0': 0.0,
#  'conv2_block1_3_conv/bias:0': 0.0,
#  'conv2_block2_preact_bn/gamma:0': 0.0,
#  'conv2_block2_preact_bn/beta:0': 0.0,
#  'conv2_block2_preact_bn/moving_mean:0': 0.000245418,
#  'conv2_block2_preact_bn/moving_variance:0': 0.0028026127,
#  'conv2_block2_1_bn/gamma:0': 0.0,
#  'conv2_block2_1_bn/beta:0': 0.0,
#  'conv2_block2_1_bn/moving_mean:0': 0.00047827454,
#  'conv2_block2_1_bn/moving_variance:0': 0.0024589375,
#  'conv2_block2_2_bn/gamma:0': 0.0,
#  'conv2_block2_2_bn/beta:0': 0.0,
#  'conv2_block2_2_bn/moving_mean:0': 0.0005269493,
#  'conv2_block2_2_bn/moving_variance:0': 0.009590916,
#  'conv2_block2_3_conv/bias:0': 0.0,
#  'conv2_block3_preact_bn/gamma:0': 0.0,
#  'conv2_block3_preact_bn/beta:0': 0.0,
#  'conv2_block3_preact_bn/moving_mean:0': 0.0002740203,
#  'conv2_block3_preact_bn/moving_variance:0': 0.003136052,
#  'conv2_block3_1_bn/gamma:0': 0.0,
#  'conv2_block3_1_bn/beta:0': 0.0,
#  'conv2_block3_1_bn/moving_mean:0': 0.00042237464,
#  'conv2_block3_1_bn/moving_variance:0': 0.002014311,
#  'conv2_block3_2_bn/gamma:0': 0.0,
#  'conv2_block3_2_bn/beta:0': 0.0,
#  'conv2_block3_2_bn/moving_mean:0': 0.00073328963,
#  'conv2_block3_2_bn/moving_variance:0': 0.009385128,
#  'conv2_block3_3_conv/bias:0': 0.0,
#  'conv3_block1_preact_bn/gamma:0': 0.0,
#  'conv3_block1_preact_bn/beta:0': 0.0,
#  'conv3_block1_preact_bn/moving_mean:0': 0.0003779811,
#  'conv3_block1_preact_bn/moving_variance:0': 0.004017856,
#  'conv3_block1_1_bn/gamma:0': 0.0,
#  'conv3_block1_1_bn/beta:0': 0.0,
#  'conv3_block1_1_bn/moving_mean:0': 0.0003481039,
#  'conv3_block1_1_bn/moving_variance:0': 0.0023700777,
#  'conv3_block1_2_bn/gamma:0': 0.0,
#  'conv3_block1_2_bn/beta:0': 0.0,
#  'conv3_block1_2_bn/moving_mean:0': 0.0010010845,
#  'conv3_block1_2_bn/moving_variance:0': 0.009318025,
#  'conv3_block1_0_conv/bias:0': 0.0,
#  'conv3_block1_3_conv/bias:0': 0.0,
#  'conv3_block2_preact_bn/gamma:0': 0.0,
#  'conv3_block2_preact_bn/beta:0': 0.0,
#  'conv3_block2_preact_bn/moving_mean:0': 0.00040018815,
#  'conv3_block2_preact_bn/moving_variance:0': 0.0019136993,
#  'conv3_block2_1_bn/gamma:0': 0.0,
#  'conv3_block2_1_bn/beta:0': 0.0,
#  'conv3_block2_1_bn/moving_mean:0': 0.000687578,
#  'conv3_block2_1_bn/moving_variance:0': 0.0044416757,
#  'conv3_block2_2_bn/gamma:0': 0.0,
#  'conv3_block2_2_bn/beta:0': 0.0,
#  'conv3_block2_2_bn/moving_mean:0': 0.0013114732,
#  'conv3_block2_2_bn/moving_variance:0': 0.0140904775,
#  'conv3_block2_3_conv/bias:0': 0.0,
#  'conv3_block3_preact_bn/gamma:0': 0.0,
#  'conv3_block3_preact_bn/beta:0': 0.0,
#  'conv3_block3_preact_bn/moving_mean:0': 0.0005714388,
#  'conv3_block3_preact_bn/moving_variance:0': 0.0024963538,
#  'conv3_block3_1_bn/gamma:0': 0.0,
#  'conv3_block3_1_bn/beta:0': 0.0,
#  'conv3_block3_1_bn/moving_mean:0': 0.0005541872,
#  'conv3_block3_1_bn/moving_variance:0': 0.0022234288,
#  'conv3_block3_2_bn/gamma:0': 0.0,
#  'conv3_block3_2_bn/beta:0': 0.0,
#  'conv3_block3_2_bn/moving_mean:0': 0.0007542592,
#  'conv3_block3_2_bn/moving_variance:0': 0.0048881024,
#  'conv3_block3_3_conv/bias:0': 0.0,
#  'conv3_block4_preact_bn/gamma:0': 0.0,
#  'conv3_block4_preact_bn/beta:0': 0.0,
#  'conv3_block4_preact_bn/moving_mean:0': 0.0006576617,
#  'conv3_block4_preact_bn/moving_variance:0': 0.0033013565,
#  'conv3_block4_1_bn/gamma:0': 0.0,
#  'conv3_block4_1_bn/beta:0': 0.0,
#  'conv3_block4_1_bn/moving_mean:0': 0.00046528733,
#  'conv3_block4_1_bn/moving_variance:0': 0.0014736606,
#  'conv3_block4_2_bn/gamma:0': 0.0,
#  'conv3_block4_2_bn/beta:0': 0.0,
#  'conv3_block4_2_bn/moving_mean:0': 0.0006088392,
#  'conv3_block4_2_bn/moving_variance:0': 0.0025744932,
#  'conv3_block4_3_conv/bias:0': 0.0,
#  'conv4_block1_preact_bn/gamma:0': 0.0,
#  'conv4_block1_preact_bn/beta:0': 0.0,
#  'conv4_block1_preact_bn/moving_mean:0': 0.00072036125,
#  'conv4_block1_preact_bn/moving_variance:0': 0.0041317362,
#  'conv4_block1_1_bn/gamma:0': 0.0,
#  'conv4_block1_1_bn/beta:0': 0.0,
#  'conv4_block1_1_bn/moving_mean:0': 0.0003645629,
#  'conv4_block1_1_bn/moving_variance:0': 0.001367595,
#  'conv4_block1_2_bn/gamma:0': 0.0,
#  'conv4_block1_2_bn/beta:0': 0.0,
#  'conv4_block1_2_bn/moving_mean:0': 0.00059144,
#  'conv4_block1_2_bn/moving_variance:0': 0.0051286006,
#  'conv4_block1_0_conv/bias:0': 0.0,
#  'conv4_block1_3_conv/bias:0': 0.0,
#  'conv4_block2_preact_bn/gamma:0': 0.0,
#  'conv4_block2_preact_bn/beta:0': 0.0,
#  'conv4_block2_preact_bn/moving_mean:0': 0.00022683454,
#  'conv4_block2_preact_bn/moving_variance:0': 0.0010575822,
#  'conv4_block2_1_bn/gamma:0': 0.0,
#  'conv4_block2_1_bn/beta:0': 0.0,
#  'conv4_block2_1_bn/moving_mean:0': 0.00018373634,
#  'conv4_block2_1_bn/moving_variance:0': 0.0020035899,
#  'conv4_block2_2_bn/gamma:0': 0.0,
#  'conv4_block2_2_bn/beta:0': 0.0,
#  'conv4_block2_2_bn/moving_mean:0': 0.0003070161,
#  'conv4_block2_2_bn/moving_variance:0': 0.00234362,
#  'conv4_block2_3_conv/bias:0': 0.0,
#  'conv4_block3_preact_bn/gamma:0': 0.0,
#  'conv4_block3_preact_bn/beta:0': 0.0,
#  'conv4_block3_preact_bn/moving_mean:0': 0.00023833197,
#  'conv4_block3_preact_bn/moving_variance:0': 0.0013185057,
#  'conv4_block3_1_bn/gamma:0': 0.0,
#  'conv4_block3_1_bn/beta:0': 0.0,
#  'conv4_block3_1_bn/moving_mean:0': 0.00016524692,
#  'conv4_block3_1_bn/moving_variance:0': 0.0011827922,
#  'conv4_block3_2_bn/gamma:0': 0.0,
#  'conv4_block3_2_bn/beta:0': 0.0,
#  'conv4_block3_2_bn/moving_mean:0': 0.000203195,
#  'conv4_block3_2_bn/moving_variance:0': 0.0014049956,
#  'conv4_block3_3_conv/bias:0': 0.0,
#  'conv4_block4_preact_bn/gamma:0': 0.0,
#  'conv4_block4_preact_bn/beta:0': 0.0,
#  'conv4_block4_preact_bn/moving_mean:0': 0.00023897822,
#  'conv4_block4_preact_bn/moving_variance:0': 0.0016271952,
#  'conv4_block4_1_bn/gamma:0': 0.0,
#  'conv4_block4_1_bn/beta:0': 0.0,
#  'conv4_block4_1_bn/moving_mean:0': 0.00011978316,
#  'conv4_block4_1_bn/moving_variance:0': 0.0010997609,
#  'conv4_block4_2_bn/gamma:0': 0.0,
#  'conv4_block4_2_bn/beta:0': 0.0,
#  'conv4_block4_2_bn/moving_mean:0': 0.00017816166,
#  'conv4_block4_2_bn/moving_variance:0': 0.0011681155,
#  'conv4_block4_3_conv/bias:0': 0.0,
#  'conv4_block5_preact_bn/gamma:0': 0.0,
#  'conv4_block5_preact_bn/beta:0': 0.0,
#  'conv4_block5_preact_bn/moving_mean:0': 0.00024209544,
#  'conv4_block5_preact_bn/moving_variance:0': 0.0020110835,
#  'conv4_block5_1_bn/gamma:0': 0.0,
#  'conv4_block5_1_bn/beta:0': 0.0,
#  'conv4_block5_1_bn/moving_mean:0': 0.000105906525,
#  'conv4_block5_1_bn/moving_variance:0': 0.001070023,
#  'conv4_block5_2_bn/gamma:0': 0.0,
#  'conv4_block5_2_bn/beta:0': 0.0,
#  'conv4_block5_2_bn/moving_mean:0': 0.00016581922,
#  'conv4_block5_2_bn/moving_variance:0': 0.0014596051,
#  'conv4_block5_3_conv/bias:0': 0.0,
#  'conv4_block6_preact_bn/gamma:0': 0.0,
#  'conv4_block6_preact_bn/beta:0': 0.0,
#  'conv4_block6_preact_bn/moving_mean:0': 0.00024500553,
#  'conv4_block6_preact_bn/moving_variance:0': 0.0025509922,
#  'conv4_block6_1_bn/gamma:0': 0.0,
#  'conv4_block6_1_bn/beta:0': 0.0,
#  'conv4_block6_1_bn/moving_mean:0': 9.6543736e-05,
#  'conv4_block6_1_bn/moving_variance:0': 0.001042465,
#  'conv4_block6_2_bn/gamma:0': 0.0,
#  'conv4_block6_2_bn/beta:0': 0.0,
#  'conv4_block6_2_bn/moving_mean:0': 0.00028201635,
#  'conv4_block6_2_bn/moving_variance:0': 0.0018517785,
#  'conv4_block6_3_conv/bias:0': 0.0,
#  'conv5_block1_preact_bn/gamma:0': 0.0,
#  'conv5_block1_preact_bn/beta:0': 0.0,
#  'conv5_block1_preact_bn/moving_mean:0': 0.0005496226,
#  'conv5_block1_preact_bn/moving_variance:0': 0.0037551182,
#  'conv5_block1_1_bn/gamma:0': 0.0,
#  'conv5_block1_1_bn/beta:0': 0.0,
#  'conv5_block1_1_bn/moving_mean:0': 0.0001147072,
#  'conv5_block1_1_bn/moving_variance:0': 0.0014249071,
#  'conv5_block1_2_bn/gamma:0': 0.0,
#  'conv5_block1_2_bn/beta:0': 0.0,
#  'conv5_block1_2_bn/moving_mean:0': 0.00039590162,
#  'conv5_block1_2_bn/moving_variance:0': 0.005322356,
#  'conv5_block1_0_conv/bias:0': 0.0,
#  'conv5_block1_3_conv/bias:0': 0.0,
#  'conv5_block2_preact_bn/gamma:0': 0.0,
#  'conv5_block2_preact_bn/beta:0': 0.0,
#  'conv5_block2_preact_bn/moving_mean:0': 0.00013941174,
#  'conv5_block2_preact_bn/moving_variance:0': 0.0010729937,
#  'conv5_block2_1_bn/gamma:0': 0.0,
#  'conv5_block2_1_bn/beta:0': 0.0,
#  'conv5_block2_1_bn/moving_mean:0': 0.00015354395,
#  'conv5_block2_1_bn/moving_variance:0': 0.004156514,
#  'conv5_block2_2_bn/gamma:0': 0.0,
#  'conv5_block2_2_bn/beta:0': 0.0,
#  'conv5_block2_2_bn/moving_mean:0': 0.00038492226,
#  'conv5_block2_2_bn/moving_variance:0': 0.006800466,
#  'conv5_block2_3_conv/bias:0': 0.0,
#  'conv5_block3_preact_bn/gamma:0': 0.0,
#  'conv5_block3_preact_bn/beta:0': 0.0,
#  'conv5_block3_preact_bn/moving_mean:0': 0.00020567678,
#  'conv5_block3_preact_bn/moving_variance:0': 0.0019438256,
#  'conv5_block3_1_bn/gamma:0': 0.0,
#  'conv5_block3_1_bn/beta:0': 0.0,
#  'conv5_block3_1_bn/moving_mean:0': 0.00018469845,
#  'conv5_block3_1_bn/moving_variance:0': 0.0049053705,
#  'conv5_block3_2_bn/gamma:0': 0.0,
#  'conv5_block3_2_bn/beta:0': 0.0,
#  'conv5_block3_2_bn/moving_mean:0': 0.00035083276,
#  'conv5_block3_2_bn/moving_variance:0': 0.00855515,
#  'conv5_block3_3_conv/bias:0': 0.0,
#  'post_bn/gamma:0': 0.0,
#  'post_bn/beta:0': 0.0,
#  'post_bn/moving_mean:0': 0.0002790669,
#  'post_bn/moving_variance:0': 0.0044081896,
#  'predictions/bias:0': 0.0}
# Out[1:7]:
# {'conv1_conv/bias:0': 0.0,
#  'conv2_block1_preact_bn/gamma:0': 0.0,
#  'conv2_block1_preact_bn/beta:0': 0.0,
#  'conv2_block1_preact_bn/moving_mean:0': 0.06999694,
#  'conv2_block1_preact_bn/moving_variance:0': 3.9937458,
#  'conv2_block1_1_bn/gamma:0': 0.0,
#  'conv2_block1_1_bn/beta:0': 0.0,
#  'conv2_block1_1_bn/moving_mean:0': 0.00016919873,
#  'conv2_block1_1_bn/moving_variance:0': 0.0052635204,
#  'conv2_block1_2_bn/gamma:0': 0.0,
#  'conv2_block1_2_bn/beta:0': 0.0,
#  'conv2_block1_2_bn/moving_mean:0': 0.0018238111,
#  'conv2_block1_2_bn/moving_variance:0': 0.011714667,
#  'conv2_block1_0_conv/bias:0': 0.0,
#  'conv2_block1_3_conv/bias:0': 0.0,
#  'conv2_block2_preact_bn/gamma:0': 0.0,
#  'conv2_block2_preact_bn/beta:0': 0.0,
#  'conv2_block2_preact_bn/moving_mean:0': 0.0002454194,
#  'conv2_block2_preact_bn/moving_variance:0': 0.0028026178,
#  'conv2_block2_1_bn/gamma:0': 0.0,
#  'conv2_block2_1_bn/beta:0': 0.0,
#  'conv2_block2_1_bn/moving_mean:0': 0.0004782826,
#  'conv2_block2_1_bn/moving_variance:0': 0.0024589542,
#  'conv2_block2_2_bn/gamma:0': 0.0,
#  'conv2_block2_2_bn/beta:0': 0.0,
#  'conv2_block2_2_bn/moving_mean:0': 0.0005269428,
#  'conv2_block2_2_bn/moving_variance:0': 0.009590842,
#  'conv2_block2_3_conv/bias:0': 0.0,
#  'conv2_block3_preact_bn/gamma:0': 0.0,
#  'conv2_block3_preact_bn/beta:0': 0.0,
#  'conv2_block3_preact_bn/moving_mean:0': 0.00027401996,
#  'conv2_block3_preact_bn/moving_variance:0': 0.0031360453,
#  'conv2_block3_1_bn/gamma:0': 0.0,
#  'conv2_block3_1_bn/beta:0': 0.0,
#  'conv2_block3_1_bn/moving_mean:0': 0.00042237257,
#  'conv2_block3_1_bn/moving_variance:0': 0.002014325,
#  'conv2_block3_2_bn/gamma:0': 0.0,
#  'conv2_block3_2_bn/beta:0': 0.0,
#  'conv2_block3_2_bn/moving_mean:0': 0.00073328894,
#  'conv2_block3_2_bn/moving_variance:0': 0.009385211,
#  'conv2_block3_3_conv/bias:0': 0.0,
#  'conv3_block1_preact_bn/gamma:0': 0.0,
#  'conv3_block1_preact_bn/beta:0': 0.0,
#  'conv3_block1_preact_bn/moving_mean:0': 0.00037797855,
#  'conv3_block1_preact_bn/moving_variance:0': 0.004017837,
#  'conv3_block1_1_bn/gamma:0': 0.0,
#  'conv3_block1_1_bn/beta:0': 0.0,
#  'conv3_block1_1_bn/moving_mean:0': 0.00034810597,
#  'conv3_block1_1_bn/moving_variance:0': 0.0023700679,
#  'conv3_block1_2_bn/gamma:0': 0.0,
#  'conv3_block1_2_bn/beta:0': 0.0,
#  'conv3_block1_2_bn/moving_mean:0': 0.0010010842,
#  'conv3_block1_2_bn/moving_variance:0': 0.009318054,
#  'conv3_block1_0_conv/bias:0': 0.0,
#  'conv3_block1_3_conv/bias:0': 0.0,
#  'conv3_block2_preact_bn/gamma:0': 0.0,
#  'conv3_block2_preact_bn/beta:0': 0.0,
#  'conv3_block2_preact_bn/moving_mean:0': 0.0004001871,
#  'conv3_block2_preact_bn/moving_variance:0': 0.0019137065,
#  'conv3_block2_1_bn/gamma:0': 0.0,
#  'conv3_block2_1_bn/beta:0': 0.0,
#  'conv3_block2_1_bn/moving_mean:0': 0.0006875663,
#  'conv3_block2_1_bn/moving_variance:0': 0.00444167,
#  'conv3_block2_2_bn/gamma:0': 0.0,
#  'conv3_block2_2_bn/beta:0': 0.0,
#  'conv3_block2_2_bn/moving_mean:0': 0.0013114808,
#  'conv3_block2_2_bn/moving_variance:0': 0.014090446,
#  'conv3_block2_3_conv/bias:0': 0.0,
#  'conv3_block3_preact_bn/gamma:0': 0.0,
#  'conv3_block3_preact_bn/beta:0': 0.0,
#  'conv3_block3_preact_bn/moving_mean:0': 0.0005714401,
#  'conv3_block3_preact_bn/moving_variance:0': 0.0024963543,
#  'conv3_block3_1_bn/gamma:0': 0.0,
#  'conv3_block3_1_bn/beta:0': 0.0,
#  'conv3_block3_1_bn/moving_mean:0': 0.0005541883,
#  'conv3_block3_1_bn/moving_variance:0': 0.002223413,
#  'conv3_block3_2_bn/gamma:0': 0.0,
#  'conv3_block3_2_bn/beta:0': 0.0,
#  'conv3_block3_2_bn/moving_mean:0': 0.000754249,
#  'conv3_block3_2_bn/moving_variance:0': 0.0048881043,
#  'conv3_block3_3_conv/bias:0': 0.0,
#  'conv3_block4_preact_bn/gamma:0': 0.0,
#  'conv3_block4_preact_bn/beta:0': 0.0,
#  'conv3_block4_preact_bn/moving_mean:0': 0.00065766124,
#  'conv3_block4_preact_bn/moving_variance:0': 0.003301362,
#  'conv3_block4_1_bn/gamma:0': 0.0,
#  'conv3_block4_1_bn/beta:0': 0.0,
#  'conv3_block4_1_bn/moving_mean:0': 0.00046529467,
#  'conv3_block4_1_bn/moving_variance:0': 0.001473661,
#  'conv3_block4_2_bn/gamma:0': 0.0,
#  'conv3_block4_2_bn/beta:0': 0.0,
#  'conv3_block4_2_bn/moving_mean:0': 0.00060884736,
#  'conv3_block4_2_bn/moving_variance:0': 0.0025744908,
#  'conv3_block4_3_conv/bias:0': 0.0,
#  'conv4_block1_preact_bn/gamma:0': 0.0,
#  'conv4_block1_preact_bn/beta:0': 0.0,
#  'conv4_block1_preact_bn/moving_mean:0': 0.00072036416,
#  'conv4_block1_preact_bn/moving_variance:0': 0.0041317237,
#  'conv4_block1_1_bn/gamma:0': 0.0,
#  'conv4_block1_1_bn/beta:0': 0.0,
#  'conv4_block1_1_bn/moving_mean:0': 0.00036456942,
#  'conv4_block1_1_bn/moving_variance:0': 0.0013675913,
#  'conv4_block1_2_bn/gamma:0': 0.0,
#  'conv4_block1_2_bn/beta:0': 0.0,
#  'conv4_block1_2_bn/moving_mean:0': 0.00059144536,
#  'conv4_block1_2_bn/moving_variance:0': 0.0051286183,
#  'conv4_block1_0_conv/bias:0': 0.0,
#  'conv4_block1_3_conv/bias:0': 0.0,
#  'conv4_block2_preact_bn/gamma:0': 0.0,
#  'conv4_block2_preact_bn/beta:0': 0.0,
#  'conv4_block2_preact_bn/moving_mean:0': 0.00022683412,
#  'conv4_block2_preact_bn/moving_variance:0': 0.0010575785,
#  'conv4_block2_1_bn/gamma:0': 0.0,
#  'conv4_block2_1_bn/beta:0': 0.0,
#  'conv4_block2_1_bn/moving_mean:0': 0.00018373814,
#  'conv4_block2_1_bn/moving_variance:0': 0.0020035917,
#  'conv4_block2_2_bn/gamma:0': 0.0,
#  'conv4_block2_2_bn/beta:0': 0.0,
#  'conv4_block2_2_bn/moving_mean:0': 0.00030700807,
#  'conv4_block2_2_bn/moving_variance:0': 0.0023436104,
#  'conv4_block2_3_conv/bias:0': 0.0,
#  'conv4_block3_preact_bn/gamma:0': 0.0,
#  'conv4_block3_preact_bn/beta:0': 0.0,
#  'conv4_block3_preact_bn/moving_mean:0': 0.00023832968,
#  'conv4_block3_preact_bn/moving_variance:0': 0.0013185078,
#  'conv4_block3_1_bn/gamma:0': 0.0,
#  'conv4_block3_1_bn/beta:0': 0.0,
#  'conv4_block3_1_bn/moving_mean:0': 0.0001652461,
#  'conv4_block3_1_bn/moving_variance:0': 0.0011827927,
#  'conv4_block3_2_bn/gamma:0': 0.0,
#  'conv4_block3_2_bn/beta:0': 0.0,
#  'conv4_block3_2_bn/moving_mean:0': 0.00020319634,
#  'conv4_block3_2_bn/moving_variance:0': 0.001404996,
#  'conv4_block3_3_conv/bias:0': 0.0,
#  'conv4_block4_preact_bn/gamma:0': 0.0,
#  'conv4_block4_preact_bn/beta:0': 0.0,
#  'conv4_block4_preact_bn/moving_mean:0': 0.00023897941,
#  'conv4_block4_preact_bn/moving_variance:0': 0.0016271941,
#  'conv4_block4_1_bn/gamma:0': 0.0,
#  'conv4_block4_1_bn/beta:0': 0.0,
#  'conv4_block4_1_bn/moving_mean:0': 0.00011978643,
#  'conv4_block4_1_bn/moving_variance:0': 0.0010997693,
#  'conv4_block4_2_bn/gamma:0': 0.0,
#  'conv4_block4_2_bn/beta:0': 0.0,
#  'conv4_block4_2_bn/moving_mean:0': 0.00017815895,
#  'conv4_block4_2_bn/moving_variance:0': 0.0011681195,
#  'conv4_block4_3_conv/bias:0': 0.0,
#  'conv4_block5_preact_bn/gamma:0': 0.0,
#  'conv4_block5_preact_bn/beta:0': 0.0,
#  'conv4_block5_preact_bn/moving_mean:0': 0.00024209372,
#  'conv4_block5_preact_bn/moving_variance:0': 0.0020110845,
#  'conv4_block5_1_bn/gamma:0': 0.0,
#  'conv4_block5_1_bn/beta:0': 0.0,
#  'conv4_block5_1_bn/moving_mean:0': 0.00010590544,
#  'conv4_block5_1_bn/moving_variance:0': 0.0010700275,
#  'conv4_block5_2_bn/gamma:0': 0.0,
#  'conv4_block5_2_bn/beta:0': 0.0,
#  'conv4_block5_2_bn/moving_mean:0': 0.0001658119,
#  'conv4_block5_2_bn/moving_variance:0': 0.0014595997,
#  'conv4_block5_3_conv/bias:0': 0.0,
#  'conv4_block6_preact_bn/gamma:0': 0.0,
#  'conv4_block6_preact_bn/beta:0': 0.0,
#  'conv4_block6_preact_bn/moving_mean:0': 0.0002450036,
#  'conv4_block6_preact_bn/moving_variance:0': 0.002550994,
#  'conv4_block6_1_bn/gamma:0': 0.0,
#  'conv4_block6_1_bn/beta:0': 0.0,
#  'conv4_block6_1_bn/moving_mean:0': 9.653775e-05,
#  'conv4_block6_1_bn/moving_variance:0': 0.0010424559,
#  'conv4_block6_2_bn/gamma:0': 0.0,
#  'conv4_block6_2_bn/beta:0': 0.0,
#  'conv4_block6_2_bn/moving_mean:0': 0.00028202383,
#  'conv4_block6_2_bn/moving_variance:0': 0.0018517761,
#  'conv4_block6_3_conv/bias:0': 0.0,
#  'conv5_block1_preact_bn/gamma:0': 0.0,
#  'conv5_block1_preact_bn/beta:0': 0.0,
#  'conv5_block1_preact_bn/moving_mean:0': 0.00054962514,
#  'conv5_block1_preact_bn/moving_variance:0': 0.00375512,
#  'conv5_block1_1_bn/gamma:0': 0.0,
#  'conv5_block1_1_bn/beta:0': 0.0,
#  'conv5_block1_1_bn/moving_mean:0': 0.000114706694,
#  'conv5_block1_1_bn/moving_variance:0': 0.0014249051,
#  'conv5_block1_2_bn/gamma:0': 0.0,
#  'conv5_block1_2_bn/beta:0': 0.0,
#  'conv5_block1_2_bn/moving_mean:0': 0.00039590616,
#  'conv5_block1_2_bn/moving_variance:0': 0.0053223437,
#  'conv5_block1_0_conv/bias:0': 0.0,
#  'conv5_block1_3_conv/bias:0': 0.0,
#  'conv5_block2_preact_bn/gamma:0': 0.0,
#  'conv5_block2_preact_bn/beta:0': 0.0,
#  'conv5_block2_preact_bn/moving_mean:0': 0.00013941138,
#  'conv5_block2_preact_bn/moving_variance:0': 0.001072994,
#  'conv5_block2_1_bn/gamma:0': 0.0,
#  'conv5_block2_1_bn/beta:0': 0.0,
#  'conv5_block2_1_bn/moving_mean:0': 0.00015354432,
#  'conv5_block2_1_bn/moving_variance:0': 0.0041565076,
#  'conv5_block2_2_bn/gamma:0': 0.0,
#  'conv5_block2_2_bn/beta:0': 0.0,
#  'conv5_block2_2_bn/moving_mean:0': 0.00038493157,
#  'conv5_block2_2_bn/moving_variance:0': 0.0068004597,
#  'conv5_block2_3_conv/bias:0': 0.0,
#  'conv5_block3_preact_bn/gamma:0': 0.0,
#  'conv5_block3_preact_bn/beta:0': 0.0,
#  'conv5_block3_preact_bn/moving_mean:0': 0.00020568086,
#  'conv5_block3_preact_bn/moving_variance:0': 0.0019438291,
#  'conv5_block3_1_bn/gamma:0': 0.0,
#  'conv5_block3_1_bn/beta:0': 0.0,
#  'conv5_block3_1_bn/moving_mean:0': 0.00018469611,
#  'conv5_block3_1_bn/moving_variance:0': 0.004905354,
#  'conv5_block3_2_bn/gamma:0': 0.0,
#  'conv5_block3_2_bn/beta:0': 0.0,
#  'conv5_block3_2_bn/moving_mean:0': 0.00035083693,
#  'conv5_block3_2_bn/moving_variance:0': 0.008555146,
#  'conv5_block3_3_conv/bias:0': 0.0,
#  'post_bn/gamma:0': 0.0,
#  'post_bn/beta:0': 0.0,
#  'post_bn/moving_mean:0': 0.0002790688,
#  'post_bn/moving_variance:0': 0.004408188,
#  'predictions/bias:0': 0.0}

# %%
# %ipcluster stop
