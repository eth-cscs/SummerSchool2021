# %% [markdown]
# ## Exercise 4. XGBoost
#
# 1. Sketch the piece-wise constant function represented by the following trees on the domain $[-1,1]$
# ```
# # Tree 1
#      (0.15)
# ```
# ```
# # Tree 2
#      (x < 0)
#      /     \
#   (0.1)   (0.2)
# ```
# ```
# # Tree 3
#      (x < 0)
#      /     \
#   (0.1)   (x < 0.5)
#           /       \
#        (0.2)     (0.1)
# ```
